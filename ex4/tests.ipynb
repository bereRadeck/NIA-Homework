# %%
# for debugging
# %matplotlib inline
from Initializer import Initializer
from DonorGenerator import DonorGenerator
from TrialGenerator import TrialGenerator
from Selector import Selector
from DE import DE
from PPP import PPP
import matplotlib.pyplot as plt
"""
Step 1: Read values of the control parameters of DE: scale
factor F, crossover rate Cr, and the population size NP from
user.
"""

# Parameter:
np=30
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.5
Cr = 0.5
iterations = 3000
runnumber = 10


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

def visualize(DE,iterations,title='Differential Evolution',ylim1=1400000,ylim2= 1550000, maxcap=1514312):
    results,time=DE.run(iterations)
    fig,ax = plt.subplots(figsize=(8,8))
    for x in range(np):
        plt.plot(results[:,x],label='Chromosome '+str(x))
        
    ax.ticklabel_format(style='plain')
    ax.axhline(maxcap)
    plt.ylim(ylim1, ylim2)
    plt.ylabel("Profit/Fitness")
    plt.xlabel("Iteration")
    print('Time needed: ',time)
    print('Best Result ', max(results[-1,:]))
    if max(results[-1,:]) >= maxcap:
        print('SUCCESS')
    else:
        print('Delta to Benchmark: ', maxcap - max(results[-1,:]))
    plt.show()

# %% [markdown]
# np=50 Cr=0.5 F=0.3

# %%
for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed:  15.883240938186646
# Best Result  1514115.5726175224
# Delta to Benchmark:  196.42738247755915
# Time needed:  15.306458473205566
# Best Result  1415983.6045686975
# Delta to Benchmark:  98328.39543130249
# Time needed:  16.206954956054688
# Best Result  1514239.3629440237
# Delta to Benchmark:  72.63705597631633
# Time needed:  15.898300647735596
# Best Result  1514305.8082884206
# Delta to Benchmark:  6.191711579449475
# Time needed:  15.613852500915527
# Best Result  1514294.0953852534
# Delta to Benchmark:  17.904614746570587
# Time needed:  15.825255393981934
# Best Result  1513231.7973910691
# Delta to Benchmark:  1080.2026089308783
# Time needed:  15.619690179824829
# Best Result  1487105.3251901977
# Delta to Benchmark:  27206.674809802324
# Time needed:  15.513662099838257
# Best Result  1514271.0133250905
# Delta to Benchmark:  40.986674909479916
# Time needed:  15.966685771942139
# Best Result  1514302.2071014834
# Delta to Benchmark:  9.792898516636342
# Time needed:  15.379500389099121
# Best Result  1514266.3491306824
# Delta to Benchmark:  45.6508693175856

# %% [markdown]
# Fewer Vectors np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Even Fewer Vectors np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Now with more Vectors np = 70

# %%
np=70
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Smaller F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Bigger F = 0.5

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.5
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Even bigger F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Smaller Crosover Rate Cr=0.3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.3
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Bigger Crossover Rate Cr=0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.7
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Crossover rate of 100%

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations, ylim1 = 0)

# %% [markdown]
# # Problem 2

# %% [markdown]
# Np = 50

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Np=100

# %%
np=100
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Crossover Rate = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# # Problem 3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# np = 30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# np = 10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# F = 0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.7
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# F = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# Cr = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# Cr = 0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
