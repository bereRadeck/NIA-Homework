# %%
# for debugging
# %matplotlib inline
from Initializer import Initializer
from DonorGenerator import DonorGenerator
from TrialGenerator import TrialGenerator
from Selector import Selector
from DE import DE
from PPP import PPP
import matplotlib.pyplot as plt
"""
Step 1: Read values of the control parameters of DE: scale
factor F, crossover rate Cr, and the population size NP from
user.
"""

# Parameter:
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000
runnumber = 5


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

def visualize(DE,iterations,title='Differential Evolution',ylim1=1400000,ylim2= 1550000, maxcap=1514312):
    results,time=DE.run(iterations)
    fig,ax = plt.subplots(figsize=(8,8))
    for x in range(np):
        plt.plot(results[:,x],label='Chromosome '+str(x))
        
    ax.ticklabel_format(style='plain')
    ax.axhline(maxcap)
    plt.ylim(ylim1, ylim2)
    plt.ylabel("Profit/Fitness")
    plt.xlabel("Iteration")
    print('Time needed:',time)
    #plt.legend()
    plt.show()

# %% [markdown]
# np=50 Cr=0.5 F=0.3

# %%
for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 16.859539031982422
# Time needed: 17.63828468322754
# Time needed: 17.83803391456604
# Time needed: 17.19847321510315
# Time needed: 16.901986598968506

# %% [markdown]
# Fewer Vectors np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 6.715043544769287
# Time needed: 7.606666088104248
# Time needed: 7.06111741065979

# %% [markdown]
# Even Fewer Vectors np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 2.1701977252960205
# Time needed: 2.1223232746124268
# Time needed: 2.086419105529785

# %% [markdown]
# Now with more Vectors np = 70

# %%
np=70
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 17.683748245239258
# Time needed: 17.09937047958374
# Time needed: 15.394827127456665

# %% [markdown]
# Smaller F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 10.832030296325684
# Time needed: 10.685419797897339
# Time needed: 10.97069239616394

# %% [markdown]
# Bigger F = 0.5

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.5
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 11.927132844924927
# Time needed: 12.987263441085815
# Time needed: 13.281392812728882

# %% [markdown]
# Even bigger F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 12.879558324813843
# Time needed: 12.752925157546997
# Time needed: 13.508869886398315

# %% [markdown]
# Smaller Crosover Rate Cr=0.3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.3
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 11.77952766418457
# Time needed: 11.920151948928833
# Time needed: 10.923816919326782

# %% [markdown]
# Bigger Crossover Rate Cr=0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.7
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 11.189107894897461
# Time needed: 10.745293617248535
# Time needed: 11.72866439819336

# %% [markdown]
# Crossover rate of 100%

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations, ylim1 = 0)
# Out:
# Time needed: 12.150506734848022
# Time needed: 13.354306936264038
# Time needed: 13.783138513565063

# %% [markdown]
# # Problem 2

# %% [markdown]
# Np = 50

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 12.430754661560059
# Time needed: 11.590002298355103
# Time needed: 12.9473717212677

# %% [markdown]
# Np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 7.284548759460449
# Time needed: 5.9381163120269775
# Time needed: 6.005937576293945

# %% [markdown]
# Np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 2.1572608947753906
# Time needed: 2.065476417541504
# Time needed: 2.078441858291626

# %% [markdown]
# Np=100

# %%
np=100
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 24.886447429656982
# Time needed: 23.843268632888794
# Time needed: 21.982212781906128

# %% [markdown]
# F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 10.958726167678833
# Time needed: 11.069395065307617
# Time needed: 12.647206783294678

# %% [markdown]
# F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 13.147840738296509
# Time needed: 12.482617139816284
# Time needed: 12.566393852233887

# %% [markdown]
# Crossover Rate = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 12.160480737686157
# Time needed: 11.815433025360107
# Time needed: 11.862276554107666

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 11.569064378738403
# Time needed: 11.1393563747406
# Time needed: 10.843986988067627

# %% [markdown]
# # Problem 3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 10.843875408172607
# Time needed: 10.054141759872437
# Time needed: 12.054760694503784

# %% [markdown]
# np = 30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 7.82310938835144
# Time needed: 8.129266023635864
# Time needed: 8.324737310409546

# %% [markdown]
# np = 10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 2.654932737350464
# Time needed: 2.9471187591552734
# Time needed: 2.8523709774017334

# %% [markdown]
# F = 0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.7
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 12.740928173065186
# Time needed: 12.478625774383545
# Time needed: 12.95905590057373

# %% [markdown]
# F = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 12.985719680786133
# Time needed: 13.903320074081421
# Time needed: 10.71836543083191

# %% [markdown]
# Cr = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 10.160858392715454
# Time needed: 10.41614031791687
# Time needed: 10.791141271591187

# %% [markdown]
# Cr = 0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 10.656493902206421
# Time needed: 10.298492193222046
# Time needed: 10.309451341629028
