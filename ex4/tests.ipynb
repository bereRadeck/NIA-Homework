# %%
# for debugging
# %matplotlib inline
from Initializer import Initializer
from DonorGenerator import DonorGenerator
from TrialGenerator import TrialGenerator
from Selector import Selector
from DE import DE
from PPP import PPP
import matplotlib.pyplot as plt
"""
Step 1: Read values of the control parameters of DE: scale
factor F, crossover rate Cr, and the population size NP from
user.
"""

# Parameter:
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

def visualize(DE,iterations,title='Differential Evolution',ylim1=1400000,ylim2= 1550000, maxcap=1514312):
    results,time=DE.run(iterations)
    fig,ax = plt.subplots(figsize=(8,8))
    for x in range(np):
        plt.plot(results[:,x],label='Chromosome '+str(x))
    ax.ticklabel_format(style='plain')
    ax.axhline(maxcap)
    plt.ylim(ylim1, ylim2)
    plt.ylabel("Profit/Fitness")
    plt.xlabel("Iteration")
    print('Time needed:',time)
    #plt.legend()
    plt.show()

# %% [markdown]
# np=50 Cr=0.5 F=0.3

# %%
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 16.90094518661499
# Time needed: 16.82017230987549
# Time needed: 17.123910427093506

# %% [markdown]
# Fewer Vectors np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 10.730305194854736
# Time needed: 9.66033148765564
# Time needed: 9.965189456939697

# %% [markdown]
# Even Fewer Vectors np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 3.4357054233551025
# Time needed: 3.4106974601745605
# Time needed: 3.3735978603363037

# %% [markdown]
# Now with more Vectors np = 70

# %%
np=70
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 25.38427186012268
# Time needed: 23.211050987243652
# Time needed: 28.28258180618286

# %% [markdown]
# Smaller F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 19.691070079803467
# Time needed: 20.185478687286377
# Time needed: 16.936042070388794

# %% [markdown]
# Bigger F = 0.5

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.5
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 20.315102577209473
# Time needed: 17.371135473251343
# Time needed: 17.130003690719604

# %% [markdown]
# Even bigger F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 17.321388244628906
# Time needed: 17.413591861724854
# Time needed: 16.588852882385254

# %% [markdown]
# Smaller Crosover Rate Cr=0.3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.3
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 17.458835124969482
# Time needed: 18.611721515655518
# Time needed: 17.974767446517944

# %% [markdown]
# Bigger Crossover Rate Cr=0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.7
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
visualize(DifferentialEvolution,iterations)
# Out:
# Time needed: 18.18013024330139
# Time needed: 18.33284616470337
# Time needed: 16.53509211540222

# %% [markdown]
# Crossover rate of 100%

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=0)
visualize(DifferentialEvolution,iterations,ylim1=0)
visualize(DifferentialEvolution,iterations,ylim1=0)
# Out:
# Time needed: 18.674612760543823
# Time needed: 16.042916297912598
# Time needed: 17.243633270263672

# %% [markdown]
# # Problem 2

# %% [markdown]
# Np = 50

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 9.922961711883545
# Time needed: 10.829323291778564
# Time needed: 11.34493112564087

# %% [markdown]
# Np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 6.391336679458618
# Time needed: 6.860131025314331
# Time needed: 7.26636004447937

# %% [markdown]
# Np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 1.8283569812774658
# Time needed: 2.0939314365386963
# Time needed: 2.1408090591430664

# %% [markdown]
# Np=100

# %%
np=100
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 26.15906572341919
# Time needed: 25.54309344291687
# Time needed: 26.8622305393219

# %% [markdown]
# F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 10.579283475875854
# Time needed: 11.516890048980713
# Time needed: 12.282557010650635

# %% [markdown]
# F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 9.844797849655151
# Time needed: 10.53233528137207
# Time needed: 11.657516241073608

# %% [markdown]
# Crossover Rate = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 8.625921964645386
# Time needed: 10.938659429550171
# Time needed: 12.282592535018921

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)
# Out:
# Time needed: 11.21998119354248
# Time needed: 11.141850709915161
# Time needed: 12.095030069351196

# %% [markdown]
# # Problem 3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 8.95408010482788
# Time needed: 10.204172849655151
# Time needed: 12.329402923583984

# %% [markdown]
# np = 30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 5.313064813613892
# Time needed: 6.453773021697998
# Time needed: 6.703869104385376

# %% [markdown]
# np = 10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 2.187755823135376
# Time needed: 2.4533848762512207
# Time needed: 2.562776565551758

# %% [markdown]
# F = 0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.7
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 16.252474784851074
# Time needed: 15.91400957107544
# Time needed: 16.952555894851685

# %% [markdown]
# F = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 17.121875524520874
# Time needed: 15.462845087051392
# Time needed: 16.72730565071106

# %% [markdown]
# Cr = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 15.75096321105957
# Time needed: 16.33241868019104
# Time needed: 17.227463006973267

# %% [markdown]
# Cr = 0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
# Out:
# Time needed: 17.71527647972107
# Time needed: 15.777740240097046
# Time needed: 15.632410764694214
