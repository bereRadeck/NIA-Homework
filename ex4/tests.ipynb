# %%
# for debugging
# %matplotlib inline
from Initializer import Initializer
from DonorGenerator import DonorGenerator
from TrialGenerator import TrialGenerator
from Selector import Selector
from DE import DE
from PPP import PPP
import matplotlib.pyplot as plt
"""
Step 1: Read values of the control parameters of DE: scale
factor F, crossover rate Cr, and the population size NP from
user.
"""

# Parameter:
np=30
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.5
Cr = 0.5
iterations = 3000
runnumber = 10


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

def visualize(DE,iterations,title='Differential Evolution',ylim1=1400000,ylim2= 1550000, maxcap=1514312):
    results,time=DE.run(iterations)
    fig,ax = plt.subplots(figsize=(8,8))
    for x in range(np):
        plt.plot(results[:,x],label='Chromosome '+str(x))
        
    ax.ticklabel_format(style='plain')
    ax.axhline(maxcap)
    plt.ylim(ylim1, ylim2)
    plt.ylabel("Profit/Fitness")
    plt.xlabel("Iteration")
    print('Time needed: ',time)
    print('Best Result ', max(results[-1,:]))
    if max(results[-1,:]) >= maxcap:
        print('SUCCESS')
    #plt.legend()
    plt.show()

# %% [markdown]
# np=50 Cr=0.5 F=0.3

# %%
for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)
# Out:
# Time needed:  15.254344463348389
# Best Result  1513247.8873849465
# Time needed:  15.730183362960815
# Best Result  1513238.0049324566
# Time needed:  15.190835952758789
# Best Result  1514278.5246374942
# Time needed:  15.09513783454895
# Best Result  1514217.2516845467
# Time needed:  14.370076417922974
# Best Result  1385397.9202911584
# Time needed:  15.062541246414185
# Best Result  1514299.9559508613
# Time needed:  14.896867036819458
# Best Result  1514296.0395911513
# Time needed:  15.080935716629028
# Best Result  1514246.4615855082
# Time needed:  15.094637393951416
# Best Result  1514282.3406715074
# Time needed:  15.021437883377075
# Best Result  1514221.9236054793

# %% [markdown]
# Fewer Vectors np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Even Fewer Vectors np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Now with more Vectors np = 70

# %%
np=70
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Smaller F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Bigger F = 0.5

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.5
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Even bigger F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Smaller Crosover Rate Cr=0.3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.3
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Bigger Crossover Rate Cr=0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 0.7
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations)

# %% [markdown]
# Crossover rate of 100%

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 1
F = 0.3
Cr = 1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations, ylim1 = 0)

# %% [markdown]
# # Problem 2

# %% [markdown]
# Np = 50

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Np=30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Np=10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Np=100

# %%
np=100
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# F=0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# F=0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.8
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# Crossover Rate = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 2
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=1675000, ylim2=1850000, maxcap=1818406)

# %% [markdown]
# # Problem 3

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# np = 30

# %%
np=30
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# np = 10

# %%
np=10
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# F = 0.7

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.7
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# F = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.1
Cr = 0.5
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# Cr = 0.1

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.1
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)

# %% [markdown]
# Cr = 0.8

# %%
np=50
#xmin = 0
#xmax = 100
problemnumber = 3
F = 0.3
Cr = 0.8
iterations = 2000


#initializer = Initializer(xmin, xmax, np)
ppp = PPP(problemnumber)
initializer = Initializer(ppp, np)
donorgenerator = DonorGenerator(F)
trialgenerator = TrialGenerator(Cr,problemnumber)
selector = Selector(ppp)
de = DE


DifferentialEvolution = de(ppp, initializer, donorgenerator, trialgenerator, selector)

for i in range(runnumber):
    visualize(DifferentialEvolution,iterations,ylim1=350000, ylim2=410000, maxcap=404041)
